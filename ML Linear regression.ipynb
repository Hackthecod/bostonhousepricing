# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load boston House pricing dataset

# %%
boston = pd.read_csv(r"C:\Users\Lalit Sharma\Downloads\Datasets\boston.csv")

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston['PRICE'] = boston['MEDV']

# %%
boston.drop('MEDV',axis=1,inplace=True)

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# Summarizing the stack of the data
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
## check the missing values
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
## Exploratory data Analysis

# Correlation
boston.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns

sns.set_theme()

sns.pairplot(boston)

# %%
plt.scatter(boston['CRIM'],boston['PRICE'],color='red')
plt.title('Boston House Price Vs Crime')
plt.xlabel('Crime Rate')
plt.ylabel('Price')

plt.show()

# %%
plt.scatter(boston['RM'],boston['PRICE'],color='red')
plt.title('Boston House Price Vs RM')
plt.xlabel('RM')
plt.ylabel('Price')

plt.show()

# %%
sns.regplot(x='RM',y='PRICE',data=boston,color='red')
plt.show()

# %%
sns.regplot(x='LSTAT',y='PRICE',data=boston,color='red')
plt.show()

# %%
sns.regplot(x='CHAS',y='PRICE',data=boston,color='red')
plt.show()

# %%
sns.regplot(x='PTRATIO',y='PRICE',data=boston)
plt.show()

# %%
## Independent and Dependent Features

X = boston.iloc[:,:-1]
y = boston.iloc[:,-1]

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
## Train Test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.head()
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 5     0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0
# 116   0.13158  0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432.0
# 45    0.17142  0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233.0
# 16    1.05393  0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307.0
# 468  15.57570  0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666.0
#
#      PTRATIO       B  LSTAT
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# 45      17.9  396.90  10.21
# 16      21.0  386.85   6.58
# 468     20.2  368.74  18.13

# %%
## Standardizing the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.transform(X_train)
# Out:
# c:\Users\Lalit Sharma\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_test = scaler.transform(X_test)
# Out:
# c:\Users\Lalit Sharma\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_train
# Out:
# array([[-0.4677396 , -0.52749891, -1.79325642, ..., -8.02745672,
#         -4.13937047, -1.89183113],
#        [-0.46626435, -0.52749891, -1.63016157, ..., -8.2046666 ,
#         -4.1394793 , -1.75643177],
#        [-0.4656866 , -0.52749891, -1.69473297, ..., -8.18497661,
#         -4.1390015 , -1.79271007],
#        ...,
#        [-0.4679548 , -0.37054335, -1.79679744, ..., -8.36218649,
#         -4.13979252, -1.87636824],
#        [-0.30632832, -0.52749891, -1.46165105, ..., -7.73210691,
#         -4.17709921, -1.53380588],
#        [-0.46485508, -0.52749891, -1.66036432, ..., -7.594277  ,
#         -4.18228199, -1.7843839 ]])

# %%
X_test
# Out:
# array([[-0.46684151, -0.52749891, -1.75430529, ..., -8.44094644,
#         -4.13918731, -1.8159044 ],
#        [-0.467354  , -0.44902113, -1.70514771, ..., -8.24404657,
#         -4.1390015 , -1.9251358 ],
#        [-0.46663907, -0.52749891, -1.26085482, ..., -7.7517969 ,
#         -4.13990268, -1.63689177],
#        ...,
#        [-0.46053112, -0.52749891, -1.7095219 , ..., -8.28342654,
#         -4.14097905, -1.90332917],
#        [-0.38723778, -0.52749891, -1.46165105, ..., -7.73210691,
#         -4.1783813 , -1.67356656],
#        [-0.32424582, -0.52749891, -1.46165105, ..., -7.73210691,
#         -4.14011371, -1.66920524]])

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print coefficients & Intercept
print(regression.coef_)
# Out:
# [-9.20379069e+00  1.82517461e+01  2.37752631e+00  2.12310909e-01
#  -2.09700050e-01  2.09271666e+00 -8.25857054e+00 -6.24703086e+00
#   1.80681931e+01 -2.40628294e+02 -4.62511841e+00  8.88636258e+01
#  -2.75982392e+01]

# %%
print(regression.intercept_)
# Out:
# -268.7344228888365

# %%
## on which parameter the model have been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### prediction with test data
reg_pred = regression.predict(X_test)

# %%
reg_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %%
### plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)
plt.show()

# %%
residual = y_test - reg_pred

# %%
residual
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: PRICE, Length: 152, dtype: float64

# %%
### plotting this residuals
sns.displot(residual,kind="kde")
plt.show()

# %%
### scatter plot with respect to prediction and residuals
plt.scatter(reg_pred,residual)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.162709871457391
# 21.517444231177326
# 4.638689926172833

# %% [markdown]
# ### R square and adjusted square R square
# R^2 = 1 - SSR/SST

# %%
# R square and adjusted square R square
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)

# %%
score
# Out:
# 0.7112260057484916

# %%
# adjusted r2_score = 1 - [(1 - R2)*(n-1)/(n-k-1)]
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.6840226584639293

# %% [markdown]
# ### New data prediction

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# ...

# %% [markdown]
# ### Pickling the model file file for deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))

# %%
pickled_model.predict(X_test)
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...
